# %% [markdown]
# ## 1. Introduction to Advance NLP
# - Advanced Natural Language Processing (NLP) refers to the study and application of more complex and powerful techniques in processing human language, going beyond basic tasks like tokenization, part-of-speech tagging, and named entity recognition.
# - While traditional NLP methods focused on rule-based or statistical models, advanced NLP incorporates deep learning techniques, which allow for better handling of ambiguous, large-scale, and context-dependent language data.

# %% [markdown]
# ### More about Advanced NLP
# 1. Word Embeddings:
# Study methods like Word2Vec and GloVe to represent words as vectors in continuos space, capturing semantic relationship. These representations are crucial for understanding word meanings in context.
#
# 2. Transformers:
# The introduction of transformer models, with self-attention mechanisms, revolutionized NLP by enabling models to capture long-range dependencies and understand context beteer than previos models. This is the foundation for many modern NLP models, including BERT, GPT and T5.
#
# 3. Generative Models & Language Models
# We dive into Generative AI models like GPT and other transformer- based models. these models are designed to generate human-like text, enabling tasks such as text generation, summarization, translation, and crative writing.
#
# 4. Transfer Learning:
# We oftern use pre-trained models and fine tune them on specific tasks. this technique has made it easier to apply powerful models to a variety of language tasks with relatively small amounts of labeled data.

# %% [markdown]
# ### Word Embeddings:
# - geeks
# - ibm
# - Medium Article
# - Tensorflow
#
# Word embeddings are a way to represent words in numerical form so that computers can understand and process them more efficiently.
#
# Instead of treating words as individual tokens, word embeddings map each word to a vector (a list of numbers), where the numbers represent the word's meaning in relation to other words.
#
# ![image.png](attachment:6fb71536-436f-45e3-bc18-badc97b14f6f.png)![image.png](attachment:d4df1039-c06e-4542-9f98-f0001f18333a.png)

# %% [markdown]
# #### Popular Word Embedding Models
# 1. Word2Vec: A model that learns to represent words as vectors in a way that captures word meanings based on their context in large text data.
#
# 2. GloVe: Another popular word embedding technique which works by analysing the global co-occurrence of words in a corpus(the whole collection of text) and using this information to create word vectors.

# %% [markdown]
# ## 2. Transformers
# Transformers have fundamentally changed the way machines understand and generate human language, making them the go-to architecture of the state-of the art NLP applications today.
#
# Transformers are type of deep learning models that have revolutionized Natural Language Processing (NLP).
# They are designed to handle sequential data (like text) but in a much more efficient and powerful way compared to previous models, such as RNNs and LSTMs.

# %% [markdown]
# #### What makes Transformers Special?
# - Attention Mechanism
# - Parallel Processing
# - Positional Encoding

# %% [markdown]
# #### Transformers in Action
# - BERT (Bidirectional Encoder Representations from Transformers)
# - GPT (Generative Pre-trained Transformer)
# - T5 (Text-to-Text Transfer Transformer)
# - RoBerta (Robustly Optimized BERT Approach)
# - XLNet
# - ALBERT (A Lite BERT)
# - BART (Bidirectional and Auto-Regressive Transformers)
# - DeBARTa (Decoding-enhanced BERT with Disentangled Attention)

# %% [markdown]
# ### How do Transformers work?
# - Encoder
# - Decoder

# %% [markdown]
# #### Transformer Architecture
# - Self-Attention
# - Multi-head Attention
# - Feedforward Neural Networks
# - Layer Normalization
